# %% [markdown]
# <a href="https://colab.research.google.com/github/nagakirankys/python-binder/blob/master/pdfplumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 74.6 MB/s eta 0:00:00
# ...

# %%
import pdfplumber

# %%
pdf = pdfplumber.open("./sample_data/background-checks.pdf")

# %%
p0 = pdf.pages[0]

# %%
im = p0.to_image()
im

# %%
im.reset().debug_tablefinder()
